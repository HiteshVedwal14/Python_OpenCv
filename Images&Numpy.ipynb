# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('Computer-Vision-with-Python/DATA/00-puppy.jpg')

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
pic_arr.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (1300, 1950, 3)

# %%
# R G B

# RED CHANNEL VALUES 0-255
#plt.imshow(pic_red[:,:,0],cmap='gray')

# %%
pic_red[:,:,1] = 0

# %%
plt.imshow(pic_red)

# %%
pic_red[:,:,2] = 0
plt.imshow(pic_red)

# %%
Hit_pic = Image.open('Computer-Vision-with-Python/DATA/hitesh vedwal.JPG')

# %%
arr_pic = np.asarray(Hit_pic)
arr_pic
plt.imshow(arr_pic)

# %%
plt.imshow(arr_pic[:,:,0])

# %%
p_blue = arr_pic.copy()

# %%
p_blue[:,:,0] = 0
plt.imshow(p_blue)

# %%
p_blue[:,:,1] = 0
plt.imshow(p_blue)
